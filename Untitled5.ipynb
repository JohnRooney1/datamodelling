# %%
# Importing necessary libraries
import pandas as pd
from pycaret.regression import *

# Load the dataset from CSV
nhl_data = pd.read_csv("NHLDraftPicks2018-2023Final.csv")

# Display the first few rows of the dataset
print(nhl_data.head())
# Out:
#              Source.Name  Overall  Year              Player  \
# 0  NHLDraftPicks2018.csv        1  2018       Rasmus Dahlin
# 1  NHLDraftPicks2018.csv        2  2018   Andrei Svechnikov
# 2  NHLDraftPicks2018.csv        3  2018  Jesperi Kotkaniemi
# 3  NHLDraftPicks2018.csv        4  2018       Brady Tkachuk
# 4  NHLDraftPicks2018.csv        5  2018      Barrett Hayton
#
#                   Team  Round  Pick Position Country Height  Height (Inches)  \
# 0       Buffalo Sabres      1     1        D     SWE  6' 2"               74
# 1  Carolina Hurricanes      1     2       RW     RUS  6' 2"               74
# 2   Montréal Canadiens      1     3        C     FIN  6' 2"               74
# 3      Ottawa Senators      1     4       LW     USA  6' 3"               75
# 4      Arizona Coyotes      1     5        C     CAN  6' 1"               73
#
#    Weight Amateur League       Amateur Team
# 0     185         SWEDEN           Frolunda
# 1     192            OHL             Barrie
# ...

# %%
# Step 1: Data Preparation
# (Assuming data is already clean and preprocessed)

# Step 2: Model Setup
reg_setup = setup(data=nhl_data, target='Overall', session_id=42)

# Step 3: Model Training
best_model = compare_models()

# Step 4: Model Evaluation
evaluate_model(best_model)
# Out:
# <style type="text/css">
# #T_ed50c_row10_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_ed50c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ed50c_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_ed50c_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ed50c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ed50c_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_ed50c_row0_col1" class="data row0 col1" >42</td>
#     </tr>
#     <tr>
#       <th id="T_ed50c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_ed50c_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_ed50c_row1_col1" class="data row1 col1" >Overall</td>
#     </tr>
#     <tr>
#       <th id="T_ed50c_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
from sklearn.metrics import accuracy_score
import numpy as np

# Get the predictions from the best model
predictions = predict_model(best_model)

# Calculate correlation score
correlation_score = np.corrcoef(predictions['Overall'], predictions['Label'])[0, 1]

# Convert regression problem to classification (if needed) and calculate accuracy score
predictions['Label_Rounded'] = predictions['Label'].round()
accuracy = accuracy_score(predictions['Overall'], predictions['Label_Rounded'])

print("Correlation Score:", correlation_score)
print("Accuracy Score:", accuracy)
# Out:
# <style type="text/css">
# </style>
# <table id="T_65c44">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_65c44_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_65c44_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_65c44_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_65c44_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_65c44_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_65c44_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_65c44_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_65c44_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_65c44_row0_col0" class="data row0 col0" >Extra Trees Regressor</td>
#       <td id="T_65c44_row0_col1" class="data row0 col1" >25.3798</td>
# ...
